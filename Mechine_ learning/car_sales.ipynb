# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r"c:\Users\nabee\Downloads\ElectricCarData_Clean.csv")
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
df.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
df.tail()
# Out:
#        Brand                            Model  AccelSec  TopSpeed_KmH  \
# 98   Nissan                       Ariya 63kWh       7.5           160
# 99     Audi     e-tron S Sportback 55 quattro       4.5           210
# 100  Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101  Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102   Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 98        330              191            440         Yes        FWD
# 99        335              258            540         Yes        AWD
# 100       325              194            440         Yes        AWD
# 101       375              232            450         Yes        AWD
# 102       400              238            480         Yes        AWD
#
#        PlugType  BodyStyle Segment  Seats  PriceEuro
# 98   Type 2 CCS  Hatchback       C      5      45000
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
df.shape
# Out:
# (103, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    object
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 11.4+ KB

# %%
df.describe()
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm       Seats  \
# count  103.000000    103.000000  103.000000       103.000000  103.000000
# mean     7.396117    179.194175  338.786408       189.165049    4.883495
# std      3.017430     43.573030  126.014444        29.566839    0.795834
# min      2.100000    123.000000   95.000000       104.000000    2.000000
# 25%      5.100000    150.000000  250.000000       168.000000    5.000000
# 50%      7.300000    160.000000  340.000000       180.000000    5.000000
# 75%      9.000000    200.000000  400.000000       203.000000    5.000000
# max     22.400000    410.000000  970.000000       273.000000    7.000000
#
#            PriceEuro
# count     103.000000
# mean    55811.563107
# std     34134.665280
# min     20129.000000
# 25%     34429.500000
# 50%     45000.000000
# 75%     65000.000000
# max    215000.000000

# %%
df.isnull().sum()
# Out:
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# PriceEuro          0
# dtype: int64

# %%
n=df.select_dtypes(['float','int'])
n.columns
# Out:
# Index(['AccelSec', 'TopSpeed_KmH', 'Range_Km', 'Efficiency_WhKm', 'Seats',
#        'PriceEuro'],
#       dtype='object')

# %%
n1=df.select_dtypes(['object'])
n1.columns
# Out:
# Index(['Brand', 'Model', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment'],
#       dtype='object')

# %%
# outlier
num_cols=['AccelSec', 'TopSpeed_KmH', 'Range_Km', 'Efficiency_WhKm', 'Seats',
       'PriceEuro']
sns.boxplot(data=df[num_cols])
plt.show()

# %%
Q1=df['AccelSec'].quantile(0.25)
Q2=df['AccelSec'].quantile(0.50)
Q3=df['AccelSec'].quantile(0.75)
print(Q1,Q2,Q3)

IQR=Q3-Q1
print(IQR)

upper=Q3+1.5*IQR
print(upper)
lower=Q1-1.5*IQR
print(lower)

outlier=[]
for x in df['AccelSec']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# 5.1 7.3 9.0
# 3.9000000000000004
# 14.850000000000001
# -0.7500000000000009
# [22.4]

# %%
df1=df['AccelSec']>upper
df.loc[df1]
# Out:
#        Brand              Model  AccelSec  TopSpeed_KmH  Range_Km  \
# 68  Renault   Kangoo Maxi ZE 33      22.4           130       160
#
#     Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain PlugType BodyStyle  \
# 68              194              -          No        FWD   Type 2       SPV
#
#    Segment  Seats  PriceEuro
# 68       N      5      38000

# %%
df.drop([68],inplace=True)

# %%
outlier=[]
for x in df['AccelSec']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# []

# %%
# 2
Q1=df['TopSpeed_KmH'].quantile(0.25)
Q2=df['TopSpeed_KmH'].quantile(0.50)
Q3=df['TopSpeed_KmH'].quantile(0.75)
print("Q1:",Q1,"Q2:",Q2,"Q3:",Q3)

IQR=Q3-Q1
print("IQR:",IQR)

upper=Q3+1.5*IQR
print(upper)
lower=Q1-1.5*IQR
print(lower)

outlier=[]
for x in df['TopSpeed_KmH']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# Q1: 150.0 Q2: 162.5 Q3: 200.0
# IQR: 50.0
# 275.0
# 75.0
# [410]

# %%
df2=df['TopSpeed_KmH']>upper
df.loc[df2]
# Out:
#      Brand      Model  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 51  Tesla   Roadster        2.1           410       970              206
#
#    FastCharge_KmH RapidCharge PowerTrain    PlugType BodyStyle Segment  Seats  \
# 51            920         Yes        AWD  Type 2 CCS    Cabrio       S      4
#
#     PriceEuro
# 51     215000

# %%
df.drop([51],inplace=True)

# %%
Q1=df['Range_Km'].quantile(0.25)
Q2=df['Range_Km'].quantile(0.50)
Q3=df['Range_Km'].quantile(0.75)
print("Q1:",Q1,"Q2:",Q2,"Q3:",Q3)

IQR=Q3-Q1
print("IQR:",IQR)

upper=Q3+1.5*IQR
print(upper)
lower=Q1-1.5*IQR
print(lower)

outlier=[]
for x in df['Range_Km']:
    if((x>upper or (x<lower))):
        outlier.append(x)
print("outlier:",outlier)
# Out:
# Q1: 250.0 Q2: 340.0 Q3: 400.0
# IQR: 150.0
# 625.0
# 25.0
# outlier: [750]

# %%
df3=df['Range_Km']>upper
df.loc[df3]
# Out:
#      Brand                 Model  AccelSec  TopSpeed_KmH  Range_Km  \
# 33  Tesla   Cybertruck Tri Motor       3.0           210       750
#
#     Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain    PlugType  \
# 33              267            710         Yes        AWD  Type 2 CCS
#
#    BodyStyle Segment  Seats  PriceEuro
# 33    Pickup       N      6      75000

# %%
df.drop([33],inplace=True)

# %%
outlier=[]
for x in df['Range_Km']:
    if((x>upper or (x<lower))):
        outlier.append(x)
print("outlier:",outlier)
# Out:
# outlier: []

# %%
# 'Efficiency_WhKm'
Q1=df['Efficiency_WhKm'].quantile(0.25)
Q2=df['Efficiency_WhKm'].quantile(0.50)
Q3=df['Efficiency_WhKm'].quantile(0.75)
print("Q1:",Q1,"Q2:",Q2,"Q3:",Q3)

IQR=Q3-Q1
print("IQR:",IQR)

upper=Q3+1.5*IQR
print("upper:",upper)
lower=Q1-1.5*IQR
print("lower:",lower)

outlier=[]
for x in df['Efficiency_WhKm']:
    if((x>upper or (x<lower))):
        outlier.append(x)
print("outlier:",outlier)
# Out:
# Q1: 168.0 Q2: 180.0 Q3: 200.0
# IQR: 32.0
# upper: 248.0
# lower: 120.0
# outlier: [104, 261, 273, 256, 270, 258]

# %%
df4=df['Efficiency_WhKm']>upper
df.loc[df4]
# Out:
#         Brand                          Model  AccelSec  TopSpeed_KmH  \
# 67     Tesla           Cybertruck Dual Motor       5.0           190
# 84  Mercedes                    EQV 300 Long      10.0           140
# 86     Tesla         Cybertruck Single Motor       7.0           180
# 90      Audi             e-tron S 55 quattro       4.5           210
# 99      Audi   e-tron S Sportback 55 quattro       4.5           210
#
#     Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 67       460              261            710         Yes        AWD
# 84       330              273            290         Yes        FWD
# 86       390              256            740         Yes        RWD
# 90       320              270            510         Yes        AWD
# 99       335              258            540         Yes        AWD
#
#       PlugType BodyStyle Segment  Seats  PriceEuro
# 67  Type 2 CCS    Pickup       N      6      55000
# ...

# %%
df.drop([67,84,86,90,99],inplace=True)

# %%
df4=df['Efficiency_WhKm']<lower
df.loc[df4]
# Out:
#          Brand Model  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 48  Lightyear   One       10.0           150       575              104
#
#    FastCharge_KmH RapidCharge PowerTrain    PlugType BodyStyle Segment  Seats  \
# 48            540         Yes        AWD  Type 2 CCS  Liftback       F      5
#
#     PriceEuro
# 48     149000

# %%
df.drop([48],inplace=True)

# %%
outlier=[]
for x in df['Efficiency_WhKm']:
    if((x>upper or (x<lower))):
        outlier.append(x)
print("outlier:",outlier)
# Out:
# outlier: []

# %%
#  'Seats'
Q1=df[ 'Seats'].quantile(0.25)
Q2=df[ 'Seats'].quantile(0.50)
Q3=df[ 'Seats'].quantile(0.75)
print("Q1:",Q1,"Q2:",Q2,"Q3:",Q3)

IQR=Q3-Q1
print("IQR:",IQR)

upper=Q3+1.5*IQR
print("upper:",upper)
lower=Q1-1.5*IQR
print("lower:",lower)

outlier=[]
for x in df[ 'Seats']:
    if((x>upper or (x<lower))):
        outlier.append(x)
print("outlier:",outlier)
# Out:
# Q1: 5.0 Q2: 5.0 Q3: 5.0
# IQR: 0.0
# upper: 5.0
# lower: 5.0
# outlier: [4, 4, 4, 4, 4, 7, 4, 4, 4, 4, 4, 4, 7, 4, 4, 7, 4, 7, 4, 4, 4, 4, 7, 2, 4, 2, 4]

# %%
df5=df[ 'Seats']>upper
df.loc[df5].index
# Out:
# Index([21, 54, 61, 66, 81], dtype='int64')

# %%
df.drop([21,54,61,66,81],inplace=True)

# %%
df5=df[ 'Seats']<lower
df.loc[df5].index
# Out:
# Index([ 4, 15, 16, 17, 19, 23, 28, 37, 43, 44, 47, 55, 57, 65, 70, 72, 77, 79,
#        82, 85, 91, 94],
#       dtype='int64')

# %%
df.drop([4,15,16,17,19,23,28,37,43,44,47,55,57,65,70,72,77,79,82,85,91,94],inplace=True)

# %%
outlier=[]
for x in df[ 'Seats']:
    if((x>upper or (x<lower))):
        outlier.append(x)
print("outlier:",outlier)
# Out:
# outlier: []

# %%
# 'PriceEuro'

Q1=df['PriceEuro'].quantile(0.25)
Q2=df['PriceEuro'].quantile(0.50)
Q3=df['PriceEuro'].quantile(0.75)
print("Q1:",Q1,"Q2:",Q2,"Q3:",Q3)

IQR=Q3-Q1
print("IQR:",IQR)

upper=Q3+1.5*IQR
print("upper:",upper)
lower=Q1-1.5*IQR
print("lower:",lower)

outlier=[]
for x in df['PriceEuro']:
    if((x>upper or (x<lower))):
        outlier.append(x)
print("outlier:",outlier)
# Out:
# Q1: 34729.5 Q2: 45000.0 Q3: 58968.5
# IQR: 24239.0
# upper: 95327.0
# lower: -1629.0
# outlier: [105000, 96990]

# %%
df6=df['PriceEuro']>upper
df.loc[df6].index
# Out:
# Index([5, 59], dtype='int64')

# %%
df.drop([5,59],inplace=True)

# %%
outlier=[]
for x in df['PriceEuro']:
    if((x>upper or (x<lower))):
        outlier.append(x)
print("outlier:",outlier)
# Out:
# outlier: []

# %%
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 6    Volkswagen                           e-Golf        9.6           150
# ..           ...                              ...       ...           ...
# 97        Byton                 M-Byte 72 kWh 2WD       7.5           190
# 98       Nissan                       Ariya 63kWh       7.5           160
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
# encoding,one hot
df.Brand.nunique()
# Out:
# 24

# %%
df.Model.nunique()
# Out:
# 64

# %%
df.drop(['Model'],axis=1,inplace=True)

# %%
# df1=pd.get_dummies(df)
# df1

# %%
# df_1=pd.get_dummies(df1)
# df_1.astype('int')

# %%
# label encoding

df.head()
# Out:
#          Brand  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 0       Tesla        4.6           233       450              161
# 1  Volkswagen       10.0           160       270              167
# 2    Polestar        4.7           210       400              181
# 3         BMW        6.8           180       360              206
# 4  Volkswagen        9.6           150       190              168
#
#   FastCharge_KmH RapidCharge PowerTrain    PlugType  BodyStyle Segment  Seats  \
# 0            940         Yes        AWD  Type 2 CCS      Sedan       D      5
# 1            250         Yes        RWD  Type 2 CCS  Hatchback       C      5
# 2            620         Yes        AWD  Type 2 CCS   Liftback       D      5
# 3            560         Yes        RWD  Type 2 CCS        SUV       D      5
# 4            220         Yes        FWD  Type 2 CCS  Hatchback       C      5
#
#    PriceEuro
# 0      55480
# 1      30000
# 2      56440
# 3      68040
# 4      31900

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.head()
# Out:
#          Brand  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 0       Tesla        4.6           233       450              161
# 1  Volkswagen       10.0           160       270              167
# 2    Polestar        4.7           210       400              181
# 3         BMW        6.8           180       360              206
# 4  Volkswagen        9.6           150       190              168
#
#   FastCharge_KmH RapidCharge PowerTrain    PlugType  BodyStyle Segment  Seats  \
# 0            940         Yes        AWD  Type 2 CCS      Sedan       D      5
# 1            250         Yes        RWD  Type 2 CCS  Hatchback       C      5
# 2            620         Yes        AWD  Type 2 CCS   Liftback       D      5
# 3            560         Yes        RWD  Type 2 CCS        SUV       D      5
# 4            220         Yes        FWD  Type 2 CCS  Hatchback       C      5
#
#    PriceEuro
# 0      55480
# 1      30000
# 2      56440
# 3      68040
# 4      31900

# %%
for i in ['Brand','RapidCharge','PowerTrain','PlugType','BodyStyle','Segment']:
    df[i]=le.fit_transform(df[i])
    df[i]

# %%
df
# Out:
#     Brand  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm FastCharge_KmH  \
# 0      21       4.6           233       450              161            940
# 1      22      10.0           160       270              167            250
# 2      17       4.7           210       400              181            620
# 3       2       6.8           180       360              206            560
# 4      22       9.6           150       190              168            220
# ..    ...       ...           ...       ...              ...            ...
# 60      3       7.5           190       325              222            420
# 61     14       7.5           160       330              191            440
# 62     14       5.9           200       325              194            440
# 63     14       5.1           200       375              232            450
# 64      3       7.5           190       400              238            480
#
# ...

# %%
# scaling
x=df.drop(['PriceEuro','Brand','RapidCharge','PowerTrain','PlugType','BodyStyle','Segment'],axis=1)

# %%
y=df[['PriceEuro','Brand','RapidCharge','PowerTrain','PlugType','BodyStyle','Segment']]

# %%
x
# Out:
#     AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm FastCharge_KmH  Seats
# 0        4.6           233       450              161            940      5
# 1       10.0           160       270              167            250      5
# 2        4.7           210       400              181            620      5
# 3        6.8           180       360              206            560      5
# 4        9.6           150       190              168            220      5
# ..       ...           ...       ...              ...            ...    ...
# 60       7.5           190       325              222            420      5
# 61       7.5           160       330              191            440      5
# 62       5.9           200       325              194            440      5
# 63       5.1           200       375              232            450      5
# 64       7.5           190       400              238            480      5
#
# [65 rows x 6 columns]

# %%
y
# Out:
#     PriceEuro  Brand  RapidCharge  PowerTrain  PlugType  BodyStyle  Segment
# 0       55480     21            0           0         1          4        2
# 1       30000     22            0           2         1          0        1
# 2       56440     17            0           0         1          1        2
# 3       68040      2            0           2         1          3        2
# 4       31900     22            0           1         1          0        1
# ..        ...    ...          ...         ...       ...        ...      ...
# 60      53500      3            0           2         1          3        3
# 61      45000     14            0           1         1          0        1
# 62      50000     14            0           0         1          0        1
# 63      65000     14            0           0         1          0        1
# 64      62000      3            0           0         1          3        3
#
# [65 rows x 7 columns]

# %%
# scaling

from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler(feature_range=(0,1))

# %%
x1=minmax.fit_transform(x)
x1
# Out:
# array([[0.15      , 0.77777778, 0.80597015, 0.08791209, 1.        ,
#         0.        ],
#        [0.825     , 0.1984127 , 0.26865672, 0.15384615, 0.08      ,
#         0.        ],
#        [0.1625    , 0.5952381 , 0.65671642, 0.30769231, 0.57333333,
#         0.        ],
#        [0.425     , 0.35714286, 0.53731343, 0.58241758, 0.49333333,
#         0.        ],
#        [0.775     , 0.11904762, 0.02985075, 0.16483516, 0.04      ,
#         0.        ],
#        [0.5875    , 0.11904762, 0.28358209, 0.12087912, 0.30666667,
#         0.        ],
#        [0.275     , 0.71428571, 0.3880597 , 0.        , 0.61333333,
#         0.        ],
#        [0.3625    , 0.35714286, 0.65671642, 0.43956044, 0.46666667,
#         0.        ],
#        [0.2125    , 0.35714286, 0.56716418, 0.69230769, 0.33333333,
#         0.        ],
#        [0.5625    , 0.07142857, 0.11940299, 0.12087912, 0.05333333,
#         0.        ],
#        [0.5625    , 0.25396825, 0.65671642, 0.07692308, 0.25333333,
# ...

# %%
x
# Out:
#     AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm FastCharge_KmH  Seats
# 0        4.6           233       450              161            940      5
# 1       10.0           160       270              167            250      5
# 2        4.7           210       400              181            620      5
# 3        6.8           180       360              206            560      5
# 4        9.6           150       190              168            220      5
# ..       ...           ...       ...              ...            ...    ...
# 60       7.5           190       325              222            420      5
# 61       7.5           160       330              191            440      5
# 62       5.9           200       325              194            440      5
# 63       5.1           200       375              232            450      5
# 64       7.5           190       400              238            480      5
#
# [65 rows x 6 columns]

# %%
x2=pd.DataFrame(x1,columns=['AccelSec','TopSpeed_KmH','Range_Km','Efficiency_WhKm','FastCharge_KmH','Seats'])
x2
# Out:
#     AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH  Seats
# 0     0.1500      0.777778  0.805970         0.087912        1.000000    0.0
# 1     0.8250      0.198413  0.268657         0.153846        0.080000    0.0
# 2     0.1625      0.595238  0.656716         0.307692        0.573333    0.0
# 3     0.4250      0.357143  0.537313         0.582418        0.493333    0.0
# 4     0.7750      0.119048  0.029851         0.164835        0.040000    0.0
# ..       ...           ...       ...              ...             ...    ...
# 60    0.5125      0.436508  0.432836         0.758242        0.306667    0.0
# 61    0.5125      0.198413  0.447761         0.417582        0.333333    0.0
# 62    0.3125      0.515873  0.432836         0.450549        0.333333    0.0
# 63    0.2125      0.515873  0.582090         0.868132        0.346667    0.0
# 64    0.5125      0.436508  0.656716         0.934066        0.386667    0.0
#
# [65 rows x 6 columns]

# %%
df.describe()
# Out:
#            Brand   AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm  \
# count  65.000000  65.000000     65.000000   65.000000        65.000000
# mean   12.076923   7.381538    172.923077  336.153846       186.415385
# std     7.166126   1.845424     26.455923   73.738184        23.349178
# min     0.000000   3.400000    135.000000  180.000000       153.000000
# 25%     6.000000   6.000000    155.000000  275.000000       168.000000
# 50%    14.000000   7.500000    165.000000  340.000000       180.000000
# 75%    19.000000   8.800000    190.000000  400.000000       198.000000
# max    23.000000  11.400000    261.000000  515.000000       244.000000
#
#        RapidCharge  PowerTrain   PlugType  BodyStyle    Segment  Seats  \
# count         65.0   65.000000  65.000000  65.000000  65.000000   65.0
# mean           0.0    0.861538   1.030769   2.123077   1.261538    5.0
# std            0.0    0.747431   0.248069   1.419812   1.004318    0.0
# ...

# %%
x3=pd.concat([x2,y],axis=1)
x3
# Out:
#     AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH  Seats  \
# 0     0.1500      0.777778  0.805970         0.087912        1.000000    0.0
# 1     0.8250      0.198413  0.268657         0.153846        0.080000    0.0
# 2     0.1625      0.595238  0.656716         0.307692        0.573333    0.0
# 3     0.4250      0.357143  0.537313         0.582418        0.493333    0.0
# 4     0.7750      0.119048  0.029851         0.164835        0.040000    0.0
# ..       ...           ...       ...              ...             ...    ...
# 60    0.5125      0.436508  0.432836         0.758242        0.306667    0.0
# 61    0.5125      0.198413  0.447761         0.417582        0.333333    0.0
# 62    0.3125      0.515873  0.432836         0.450549        0.333333    0.0
# 63    0.2125      0.515873  0.582090         0.868132        0.346667    0.0
# 64    0.5125      0.436508  0.656716         0.934066        0.386667    0.0
#
# ...

# %%
# Mechine learning
# Linear regression  cheyyunna samaayth nammude datane two ayitt devide cheyyunnu.1)dependent variable,2)independent variable

# %%
df=x3

# %%
df
# Out:
#     AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH  Seats  \
# 0     0.1500      0.777778  0.805970         0.087912        1.000000    0.0
# 1     0.8250      0.198413  0.268657         0.153846        0.080000    0.0
# 2     0.1625      0.595238  0.656716         0.307692        0.573333    0.0
# 3     0.4250      0.357143  0.537313         0.582418        0.493333    0.0
# 4     0.7750      0.119048  0.029851         0.164835        0.040000    0.0
# ..       ...           ...       ...              ...             ...    ...
# 60    0.5125      0.436508  0.432836         0.758242        0.306667    0.0
# 61    0.5125      0.198413  0.447761         0.417582        0.333333    0.0
# 62    0.3125      0.515873  0.432836         0.450549        0.333333    0.0
# 63    0.2125      0.515873  0.582090         0.868132        0.346667    0.0
# 64    0.5125      0.436508  0.656716         0.934066        0.386667    0.0
#
# ...

# %%
x=df.drop(['PriceEuro'],axis=1)
x
# Out:
#     AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH  Seats  \
# 0     0.1500      0.777778  0.805970         0.087912        1.000000    0.0
# 1     0.8250      0.198413  0.268657         0.153846        0.080000    0.0
# 2     0.1625      0.595238  0.656716         0.307692        0.573333    0.0
# 3     0.4250      0.357143  0.537313         0.582418        0.493333    0.0
# 4     0.7750      0.119048  0.029851         0.164835        0.040000    0.0
# ..       ...           ...       ...              ...             ...    ...
# 60    0.5125      0.436508  0.432836         0.758242        0.306667    0.0
# 61    0.5125      0.198413  0.447761         0.417582        0.333333    0.0
# 62    0.3125      0.515873  0.432836         0.450549        0.333333    0.0
# 63    0.2125      0.515873  0.582090         0.868132        0.346667    0.0
# 64    0.5125      0.436508  0.656716         0.934066        0.386667    0.0
#
# ...

# %%
x1=pd.DataFrame(x)
x1
# Out:
#     AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH  Seats  \
# 0     0.1500      0.777778  0.805970         0.087912        1.000000    0.0
# 1     0.8250      0.198413  0.268657         0.153846        0.080000    0.0
# 2     0.1625      0.595238  0.656716         0.307692        0.573333    0.0
# 3     0.4250      0.357143  0.537313         0.582418        0.493333    0.0
# 4     0.7750      0.119048  0.029851         0.164835        0.040000    0.0
# ..       ...           ...       ...              ...             ...    ...
# 60    0.5125      0.436508  0.432836         0.758242        0.306667    0.0
# 61    0.5125      0.198413  0.447761         0.417582        0.333333    0.0
# 62    0.3125      0.515873  0.432836         0.450549        0.333333    0.0
# 63    0.2125      0.515873  0.582090         0.868132        0.346667    0.0
# 64    0.5125      0.436508  0.656716         0.934066        0.386667    0.0
#
# ...

# %%
y=df[['PriceEuro']]
y1=pd.DataFrame(y)
print(y1)
# Out:
#     PriceEuro
# 0       55480
# 1       30000
# 2       56440
# 3       68040
# 4       31900
# ..        ...
# 60      53500
# 61      45000
# 62      50000
# 63      65000
# 64      62000
#
# [65 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
model=lr.fit(x1_train,y1_train)

# %%
y1_pred=model.predict(x1_test)

# %%
y1_pred
# Out:
# array([[66263.60751925],
#        [62144.3990655 ],
#        [60689.44815272],
#        [50687.36005078],
#        [30752.34755426],
#        [44417.94535257],
#        [65511.79600278],
#        [32257.02549959],
#        [73071.80524573],
#        [27903.2935735 ],
#        [35065.96868977],
#        [33465.89588773],
#        [49535.96052922],
#        [35199.22846247],
#        [43323.61282189],
#        [40954.13901303],
#        [55511.50968079]])

# %%
y1_test
# Out:
#     PriceEuro
# 53      69551
# 60      53500
# 0       55480
# 45      45000
# 5       29682
# 61      45000
# 16      61480
# 12      34459
# 64      62000
# 30      33971
# 33      41906
# 9       29234
# 41      50000
# 13      30000
# 34      36057
# 25      37237
# 3       68040

# %%
from sklearn.metrics import r2_score
print('r2_score:',r2_score(y1_test,y1_pred))
# Out:
# r2_score: 0.7839368265018002
