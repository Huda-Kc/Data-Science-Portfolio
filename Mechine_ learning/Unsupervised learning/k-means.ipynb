# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"c:\Users\nabee\Downloads\Mall_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.shape
# Out:
# (200, 5)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
sns.boxplot(data=df)
plt.show()

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x=df.drop('Gender',axis=1)

# %%
y=df['Gender']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])
print(df.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                  15                      39
# 1           2       1   21                  15                      81
# 2           3       0   20                  16                       6
# 3           4       0   23                  16                      77
# 4           5       0   31                  17                      40

# %%
x=df.drop('Gender',axis=1)

# %%
y=df['Gender']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)
print(x_scaled)
# Out:
# [[-1.7234121  -1.42456879 -1.73899919 -0.43480148]
#  [-1.70609137 -1.28103541 -1.73899919  1.19570407]
#  [-1.68877065 -1.3528021  -1.70082976 -1.71591298]
#  [-1.67144992 -1.13750203 -1.70082976  1.04041783]
#  [-1.6541292  -0.56336851 -1.66266033 -0.39597992]
#  [-1.63680847 -1.20926872 -1.66266033  1.00159627]
#  [-1.61948775 -0.27630176 -1.62449091 -1.71591298]
#  [-1.60216702 -1.13750203 -1.62449091  1.70038436]
#  [-1.5848463   1.80493225 -1.58632148 -1.83237767]
#  [-1.56752558 -0.6351352  -1.58632148  0.84631002]
#  [-1.55020485  2.02023231 -1.58632148 -1.4053405 ]
#  [-1.53288413 -0.27630176 -1.58632148  1.89449216]
#  [-1.5155634   1.37433211 -1.54815205 -1.36651894]
#  [-1.49824268 -1.06573534 -1.54815205  1.04041783]
#  [-1.48092195 -0.13276838 -1.54815205 -1.44416206]
#  [-1.46360123 -1.20926872 -1.54815205  1.11806095]
#  [-1.4462805  -0.27630176 -1.50998262 -0.59008772]
#  [-1.42895978 -1.3528021  -1.50998262  0.61338066]
# ...

# %%
df.drop('CustomerID',axis=1, inplace=True)

# %%
x_scale_df=pd.DataFrame(x_scaled,columns=['Age','Annual Income (k$)','Spending Score (1-100)','Gender'])
x_scale_df
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)    Gender
# 0   -1.723412           -1.424569               -1.738999 -0.434801
# 1   -1.706091           -1.281035               -1.738999  1.195704
# 2   -1.688771           -1.352802               -1.700830 -1.715913
# 3   -1.671450           -1.137502               -1.700830  1.040418
# 4   -1.654129           -0.563369               -1.662660 -0.395980
# ..        ...                 ...                     ...       ...
# 195  1.654129           -0.276302                2.268791  1.118061
# 196  1.671450            0.441365                2.497807 -0.861839
# 197  1.688771           -0.491602                2.497807  0.923953
# 198  1.706091           -0.491602                2.917671 -1.250054
# 199  1.723412           -0.635135                2.917671  1.273347
#
# [200 rows x 4 columns]

# %%
x3=pd.concat([x_scale_df, y], axis=1)
x3
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)    Gender  Gender
# 0   -1.723412           -1.424569               -1.738999 -0.434801       1
# 1   -1.706091           -1.281035               -1.738999  1.195704       1
# 2   -1.688771           -1.352802               -1.700830 -1.715913       0
# 3   -1.671450           -1.137502               -1.700830  1.040418       0
# 4   -1.654129           -0.563369               -1.662660 -0.395980       0
# ..        ...                 ...                     ...       ...     ...
# 195  1.654129           -0.276302                2.268791  1.118061       0
# 196  1.671450            0.441365                2.497807 -0.861839       0
# 197  1.688771           -0.491602                2.497807  0.923953       1
# 198  1.706091           -0.491602                2.917671 -1.250054       1
# 199  1.723412           -0.635135                2.917671  1.273347       1
#
# [200 rows x 5 columns]

# %%
# Why K-Means?

# To group similar customers without using a target variable.

# Why Scaling?

# K-Means uses distance calculations, so all features must be on a similar scale.

# Why Elbow Method?

# To find the optimal number of clusters.

# %%
from sklearn.cluster import KMeans

# %%
sse=[]

for i in range(1,11):
    kmeans=KMeans(n_clusters=i,random_state=42)
    kmeans.fit(x_scaled)
    sse.append(kmeans.inertia_)

plt.plot(range(1,11),sse,marker='o')
plt.show()

# %%
kmeans=KMeans(n_clusters=4,random_state=42)
clusters= kmeans.fit_predict(x_scaled)

# %%
df['Cluster'] = clusters

# %%
df['Cluster'].head(4)
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# Name: Cluster, dtype: int32

# %%
df['Cluster'].value_counts()
# Out:
# Cluster
# 0    60
# 2    59
# 1    41
# 3    40
# Name: count, dtype: int64

# %%
from scipy.cluster.hierarchy import dendrogram,linkage

# %%
plt.figure(figsize=(10,5))

dendrogram(linkage(x_scaled,method='ward'))

plt.axhline(y=14, color='red', linestyle='--', linewidth=2)

plt.xlabel('data points')
plt.ylabel('Euclidean distance')
plt.show()
