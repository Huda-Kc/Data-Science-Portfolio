# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r"c:\Users\nabee\Downloads\MBA_ADMISSIONS.csv")
df
# Out:
#      pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 0    75.000000            22                    71.0                    74.8
# 1    71.666667            25                    77.6                    82.6
# 2    76.666667            26                    93.2                    83.8
# 3    66.666667            22                    91.2                    80.0
# 4    71.666667            24                    79.8                    61.6
# ..         ...           ...                     ...                     ...
# 468  71.666667            22                    95.0                    78.6
# 469  71.666667            25                    77.6                    82.6
# 470  76.666667            26                    93.2                    83.8
# 471  66.666667            22                    91.2                    80.0
# 472  71.666667            24                    79.8                    61.6
#
# ...

# %%
df.head()
# Out:
#    pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 0  75.000000            22                    71.0                    74.8
# 1  71.666667            25                    77.6                    82.6
# 2  76.666667            26                    93.2                    83.8
# 3  66.666667            22                    91.2                    80.0
# 4  71.666667            24                    79.8                    61.6
#
#    Percentage_in_Under_Graduate  percentage_MBA  post_score  Gender  \
# 0                         72.00           61.00   83.333333    Male
# 1                         76.90           66.85   76.666667    Male
# 2                         77.00           74.97   75.000000  Female
# 3                         67.00           68.30   60.000000    Male
# 4                         60.33           69.28   76.666667  Female
#
#           STATE Previous_Degree Marital_status Place_you_belong_to  \
# ...

# %%
df.tail()
# Out:
#      pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 468  71.666667            22                    95.0                    78.6
# 469  71.666667            25                    77.6                    82.6
# 470  76.666667            26                    93.2                    83.8
# 471  66.666667            22                    91.2                    80.0
# 472  71.666667            24                    79.8                    61.6
#
#      Percentage_in_Under_Graduate  percentage_MBA  post_score  Gender  \
# 468                         75.43           68.54   88.333333    Male
# 469                         76.90           66.85   76.666667    Male
# 470                         77.00           74.97   75.000000  Female
# 471                         67.00           68.30   60.000000    Male
# 472                         60.33           69.28   76.666667  Female
#
#             STATE Previous_Degree Marital_status Place_you_belong_to  \
# ...

# %%
df.shape
# Out:
# (473, 14)

# %%
df.columns
# Out:
# Index(['pre_score', 'Age_in_years', 'Percentage_in_10_Class',
#        'Percentage_in_12_Class', 'Percentage_in_Under_Graduate',
#        'percentage_MBA', 'post_score', 'Gender', 'STATE', 'Previous_Degree',
#        'Marital_status', 'Place_you_belong_to', 'perceived#Job#Skill',
#        'Specialization'],
#       dtype='object')

# %%
df.describe()
# Out:
#         pre_score  Age_in_years  Percentage_in_10_Class  \
# count  473.000000    473.000000              473.000000
# mean    68.181818     22.560254               84.018541
# std     13.844486      1.707742                8.225745
# min     30.000000     19.000000               58.900000
# 25%     60.000000     21.000000               79.000000
# 50%     70.000000     22.000000               85.000000
# 75%     76.666667     24.000000               90.000000
# max    100.000000     26.000000               97.200000
#
#        Percentage_in_12_Class  Percentage_in_Under_Graduate  percentage_MBA  \
# count               473.00000                    473.000000      473.000000
# mean                 81.55611                     73.405137       67.874165
# std                   9.77328                      7.650524        3.760739
# min                  60.29000                     58.000000       57.000000
# 25%                  75.20000                     67.880000       65.600000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473 entries, 0 to 472
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   pre_score                     473 non-null    float64
#  1   Age_in_years                  473 non-null    int64
#  2   Percentage_in_10_Class        473 non-null    float64
#  3   Percentage_in_12_Class        473 non-null    float64
#  4   Percentage_in_Under_Graduate  473 non-null    float64
#  5   percentage_MBA                473 non-null    float64
#  6   post_score                    473 non-null    float64
#  7   Gender                        473 non-null    object
#  8   STATE                         473 non-null    object
#  9   Previous_Degree               473 non-null    object
#  10  Marital_status                473 non-null    object
#  11  Place_you_belong_to           473 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# pre_score                       0
# Age_in_years                    0
# Percentage_in_10_Class          0
# Percentage_in_12_Class          0
# Percentage_in_Under_Graduate    0
# percentage_MBA                  0
# post_score                      0
# Gender                          0
# STATE                           0
# Previous_Degree                 0
# Marital_status                  0
# Place_you_belong_to             0
# perceived#Job#Skill             0
# Specialization                  0
# dtype: int64

# %%
m=df.select_dtypes(include=['float','int'])
m.columns
# Out:
# Index(['pre_score', 'Age_in_years', 'Percentage_in_10_Class',
#        'Percentage_in_12_Class', 'Percentage_in_Under_Graduate',
#        'percentage_MBA', 'post_score'],
#       dtype='object')

# %%
n=df.select_dtypes(include=['object'])
n.columns
# Out:
# Index(['Gender', 'STATE', 'Previous_Degree', 'Marital_status',
#        'Place_you_belong_to', 'perceived#Job#Skill', 'Specialization'],
#       dtype='object')

# %%
# outlier 
cols=['pre_score', 'Age_in_years', 'Percentage_in_10_Class',
       'Percentage_in_12_Class', 'Percentage_in_Under_Graduate',
       'percentage_MBA', 'post_score']
sns.boxplot(data=df[cols])
plt.xticks(rotation=45)
plt.show()

# %%
Q1=df['pre_score'].quantile(0.25)
Q2=df['pre_score'].quantile(0.50)
Q3=df['pre_score'].quantile(0.75)

print("Q1:",Q1)
print("Q2:",Q2)
print("Q3:",Q3)

IQR=Q3-Q1
print("IQR:",IQR)


upper=Q3+1.5*IQR
print("upper:",upper)
lower=Q1-1.5*IQR
print("lower:",IQR)

outlier=[]
for x in df['pre_score']:
    if((x>upper or (x<lower))):
        outlier.append(x)
print("outlier:",outlier)
# Out:
# Q1: 60.0
# Q2: 70.0
# Q3: 76.66666667
# IQR: 16.666666669999998
# upper: 101.66666667499999
# lower: 16.666666669999998
# outlier: [30.0, 30.0, 30.0, 33.33333333, 33.33333333]

# %%
df=df[(df['pre_score']>=lower) & (df['pre_score']<=upper)]

# %%
outlier=[]
for x in df['pre_score']:
    if((x>upper or (x<lower))):
        outlier.append(x)
print("outlier:",outlier)
# Out:
# outlier: []

# %%
Q1=df[ 'Age_in_years'].quantile(0.25)
Q2=df[ 'Age_in_years'].quantile(0.50)
Q3=df['Age_in_years'].quantile(0.75)
print(Q1)
print(Q2)
print(Q3)


IQR=Q3-Q1
print(IQR)

upper=Q3+1.5*IQR
print(upper)
lower=Q1-1.5*IQR
print(lower)

outlier=[]
for x in df['Age_in_years']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# 21.0
# 22.0
# 24.0
# 3.0
# 28.5
# 16.5
# []

# %%
# 'Percentage_in_10_Class'

Q1=df['Percentage_in_10_Class'].quantile(0.25)
Q2=df['Percentage_in_10_Class'].quantile(0.50)
Q3=df['Percentage_in_10_Class'].quantile(0.75)
print(Q1)
print(Q2)
print(Q3)


IQR=Q3-Q1
print(IQR)

upper=Q3+1.5*IQR
print(upper)
lower=Q1-.15*IQR
print(lower)

outlier=[]
for x  in df['Percentage_in_10_Class']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# 79.0
# 85.0
# 90.0
# 11.0
# 106.5
# 77.35
# [71.0,
#  67.0,
#  71.0,
#  67.0,
#  72.0,
#  69.6,
#  76.0,
#  75.75,
#  77.0,
#  72.0,
#  69.6,
#  76.0,
#  75.75,
#  77.0,
#  72.0,
#  77.0,
#  76.0,
#  75.75,
#  71.67,
#  71.67,
#  75.0,
#  72.0,
#  70.4,
#  74.1,
#  58.9,
#  68.0,
#  70.0,
#  75.0,
#  72.0,
#  70.4,
#  74.1,
#  58.9,
#  68.0,
#  70.0,
#  75.0,
#  74.1,
#  58.9,
#  68.0,
#  70.0,
#  75.0,
#  70.4,
#  58.9,
#  72.0,
#  68.0,
#  68.0,
#  75.36,
#  70.0,
#  66.5,
#  76.0,
#  70.3,
#  74.1,
#  75.8,
#  72.0,
#  68.0,
#  68.0,
#  75.36,
#  70.0,
#  66.5,
#  76.0,
#  70.3,
#  74.1,
#  75.8,
#  72.0,
#  68.0,
#  68.0,
#  75.36,
#  70.0,
#  66.5,
#  76.0,
#  70.3,
#  72.0,
#  68.0,
#  68.0,
#  70.0,
#  66.5,
#  74.1,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  71.0,
#  67.0,
#  71.0,
#  67.0]

# %%
df=df[(df['Percentage_in_10_Class']>=lower)& (df['Percentage_in_10_Class']<=upper)]

# %%
outlier=[]
for x  in df['Percentage_in_10_Class']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# []

# %%
Q1=df[ 'Percentage_in_Under_Graduate'].quantile(0.25)
Q2=df[ 'Percentage_in_Under_Graduate'].quantile(0.50)
Q3=df[ 'Percentage_in_Under_Graduate'].quantile(0.75)
print(Q1)
print(Q2)
print(Q3)

IQR=Q3-Q1
print(IQR)

upper=Q3+1.5*IQR
print(upper)
lower=Q1-1.5*IQR
print(lower)

outlier=[]
for x in df[ 'Percentage_in_Under_Graduate']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# 69.25
# 75.0
# 78.8
# 9.549999999999997
# 93.125
# 54.925000000000004
# [94.0, 94.0, 94.0, 94.0]

# %%
df=df[(df[ 'Percentage_in_Under_Graduate']>=lower) & (df[ 'Percentage_in_Under_Graduate']<=upper)]

# %%
outlier=[]
for x in df[ 'Percentage_in_Under_Graduate']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# []

# %%
#        'percentage_MBA', 'post_score'
Q1=df[       'percentage_MBA'].quantile(0.25)
Q2=df['percentage_MBA'].quantile(0.50)
Q3=df['percentage_MBA'].quantile(0.75)
print(Q1)
print(Q2)
print(Q3)

IQR=Q3-Q1
print(IQR)

upper=Q3+1.5*IQR
print(upper)
lower=Q1-1.5*IQR
print(lower)

outlier=[]
for x in df['percentage_MBA']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# 66.54
# 68.48
# 70.64750000000001
# 4.107500000000002
# 76.80875
# 60.378750000000004
# [60.0, 77.41, 76.83, 57.0, 60.0, 77.41, 76.83, 57.0, 60.0, 76.83, 60.0, 77.41]

# %%
df=df[(df['percentage_MBA']>=lower)& (df['percentage_MBA']<=upper)]

# %%
outlier=[]
for x in df['percentage_MBA']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# []

# %%
Q1=df['post_score'].quantile(0.25)
Q2=df['post_score'].quantile(0.50)
Q3=df['post_score'].quantile(0.75)
print(Q1)
print(Q2)
print(Q3)


IQR=Q3-Q1
print(IQR)

upper=Q3+1.5*IQR
print(upper)
lower=Q1-1.5*IQR
print(lower)

outlier=[]
for x in df['post_score']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# 70.0
# 76.66666667
# 85.0
# 15.0
# 107.5
# 47.5
# [7.0, 7.0, 8.0, 35.0, 8.0, 35.0, 35.0, 45.0, 45.0, 45.0]

# %%
df1=df['post_score']<lower
df.loc[df1]
# Out:
#      pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 33   43.000000            23                    79.0                    70.0
# 54   43.000000            23                    79.0                    70.0
# 250  76.666667            24                    86.0                    69.0
# 257  76.666667            23                    91.2                    90.0
# 337  76.666667            24                    86.0                    69.0
# 344  76.666667            23                    91.2                    90.0
# 388  76.666667            23                    91.2                    90.0
# 430  65.000000            25                    85.6                    74.8
# 435  65.000000            25                    85.6                    74.8
# 442  65.000000            25                    85.6                    74.8
#
#      Percentage_in_Under_Graduate  percentage_MBA  post_score  Gender  \
# ...

# %%
df.drop((df.loc[df1].index),inplace=True)

# %%
outlier=[]
for x in df['post_score']:
    if((x>upper or (x<lower))):
        outlier.append(x)
outlier
# Out:
# []

# %%
df
# Out:
#      pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 1    71.666667            25                    77.6                    82.6
# 2    76.666667            26                    93.2                    83.8
# 3    66.666667            22                    91.2                    80.0
# 4    71.666667            24                    79.8                    61.6
# 6    73.333333            22                    82.0                    70.0
# ..         ...           ...                     ...                     ...
# 468  71.666667            22                    95.0                    78.6
# 469  71.666667            25                    77.6                    82.6
# 470  76.666667            26                    93.2                    83.8
# 471  66.666667            22                    91.2                    80.0
# 472  71.666667            24                    79.8                    61.6
#
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
# encoding
df.STATE.nunique()
# Out:
# 6

# %%
df.Previous_Degree.nunique()
# Out:
# 5

# %%
# one hot encoding

# df1=pd.get_dummies(df)
# df1

# %%
# df_1=pd.get_dummies(df1)
# df_1
# df_1.astype('int')

# %%
# label_encoding
df.head()
# Out:
#    pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 0  71.666667            25                    77.6                    82.6
# 1  76.666667            26                    93.2                    83.8
# 2  66.666667            22                    91.2                    80.0
# 3  71.666667            24                    79.8                    61.6
# 4  73.333333            22                    82.0                    70.0
#
#    Percentage_in_Under_Graduate  percentage_MBA  post_score  Gender  \
# 0                         76.90           66.85   76.666667    Male
# 1                         77.00           74.97   75.000000  Female
# 2                         67.00           68.30   60.000000    Male
# 3                         60.33           69.28   76.666667  Female
# 4                         76.50           67.00   81.666667    Male
#
#           STATE Previous_Degree Marital_status Place_you_belong_to  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for i in ['Gender','STATE','Previous_Degree','Marital_status','Place_you_belong_to','perceived#Job#Skill','Specialization']:
    df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 0  71.666667            25                    77.6                    82.6
# 1  76.666667            26                    93.2                    83.8
# 2  66.666667            22                    91.2                    80.0
# 3  71.666667            24                    79.8                    61.6
# 4  73.333333            22                    82.0                    70.0
#
#    Percentage_in_Under_Graduate  percentage_MBA  post_score  Gender  STATE  \
# 0                         76.90           66.85   76.666667       1      0
# 1                         77.00           74.97   75.000000       0      0
# 2                         67.00           68.30   60.000000       1      0
# 3                         60.33           69.28   76.666667       0      0
# 4                         76.50           67.00   81.666667       1      0
#
# ...

# %%
# scaling
# first choose dependent variable,bakki encode chayhtha categorical colum add cheyyuka
x=df.drop(['perceived#Job#Skill','Gender','STATE','Previous_Degree','Marital_status','Place_you_belong_to','Specialization'],axis=1)

# %%
y=df[['perceived#Job#Skill','Gender','STATE','Previous_Degree','Marital_status','Place_you_belong_to','Specialization']]

# %%
y
# Out:
#      perceived#Job#Skill  Gender  STATE  Previous_Degree  Marital_status  \
# 0                      1       1      0                2               1
# 1                      0       0      0                2               1
# 2                      1       1      0                1               1
# 3                      1       0      0                2               1
# 4                      1       1      0                2               1
# ..                   ...     ...    ...              ...             ...
# 353                    1       1      0                2               1
# 354                    1       1      0                2               1
# 355                    0       0      0                2               1
# 356                    1       1      0                1               1
# 357                    1       0      0                2               1
#
#      Place_you_belong_to  Specialization
# 0                      1               2
# ...

# %%
from sklearn.preprocessing  import MinMaxScaler

# %%
minmax=MinMaxScaler(feature_range=(0,1))

# %%
# scaling :change varenda values ann Xil ullath

# %%
x
# Out:
#      pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 0    71.666667            25                    77.6                    82.6
# 1    76.666667            26                    93.2                    83.8
# 2    66.666667            22                    91.2                    80.0
# 3    71.666667            24                    79.8                    61.6
# 4    73.333333            22                    82.0                    70.0
# ..         ...           ...                     ...                     ...
# 353  71.666667            22                    95.0                    78.6
# 354  71.666667            25                    77.6                    82.6
# 355  76.666667            26                    93.2                    83.8
# 356  66.666667            22                    91.2                    80.0
# 357  71.666667            24                    79.8                    61.6
#
# ...

# %%
x1=minmax.fit_transform(x)
x1
# Out:
# array([[0.55263158, 0.85714286, 0.        , ..., 0.5106383 , 0.42837653,
#         0.53333333],
#        [0.63157895, 1.        , 0.79591837, ..., 0.51367781, 0.98226467,
#         0.5       ],
#        [0.47368421, 0.42857143, 0.69387755, ..., 0.20972644, 0.52728513,
#         0.2       ],
#        ...,
#        [0.63157895, 1.        , 0.79591837, ..., 0.51367781, 0.98226467,
#         0.5       ],
#        [0.47368421, 0.42857143, 0.69387755, ..., 0.20972644, 0.52728513,
#         0.2       ],
#        [0.55263158, 0.71428571, 0.1122449 , ..., 0.00699088, 0.5941337 ,
#         0.53333333]], shape=(358, 7))

# %%
x2=pd.DataFrame(x1,columns=['pre_score', 'Age_in_years', 'Percentage_in_10_Class','Percentage_in_12_Class', 'Percentage_in_Under_Graduate','post_score','percentage_MBA'])
x2
# Out:
#      pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 0     0.552632      0.857143                0.000000                0.614770
# 1     0.631579      1.000000                0.795918                0.647837
# 2     0.473684      0.428571                0.693878                0.543125
# 3     0.552632      0.714286                0.112245                0.036098
# 4     0.578947      0.428571                0.224490                0.267567
# ..         ...           ...                     ...                     ...
# 353   0.552632      0.428571                0.887755                0.504547
# 354   0.552632      0.857143                0.000000                0.614770
# 355   0.631579      1.000000                0.795918                0.647837
# 356   0.473684      0.428571                0.693878                0.543125
# 357   0.552632      0.714286                0.112245                0.036098
#
# ...

# %%
y
# Out:
#      perceived#Job#Skill  Gender  STATE  Previous_Degree  Marital_status  \
# 0                      1       1      0                2               1
# 1                      0       0      0                2               1
# 2                      1       1      0                1               1
# 3                      1       0      0                2               1
# 4                      1       1      0                2               1
# ..                   ...     ...    ...              ...             ...
# 353                    1       1      0                2               1
# 354                    1       1      0                2               1
# 355                    0       0      0                2               1
# 356                    1       1      0                1               1
# 357                    1       0      0                2               1
#
#      Place_you_belong_to  Specialization
# 0                      1               2
# ...

# %%
df.describe()
# Out:
#         pre_score  Age_in_years  Percentage_in_10_Class  \
# count  358.000000    358.000000              358.000000
# mean    68.348231     22.726257               86.883352
# std     13.369806      1.692936                5.426881
# min     36.666667     19.000000               77.600000
# 25%     60.000000     22.000000               82.475000
# 50%     70.000000     22.000000               87.000000
# 75%     76.666667     24.000000               91.200000
# max    100.000000     26.000000               97.200000
#
#        Percentage_in_12_Class  Percentage_in_Under_Graduate  percentage_MBA  \
# count              358.000000                    358.000000      358.000000
# mean                82.305084                     74.194469       68.621927
# std                  9.428629                      7.117853        3.132137
# min                 60.290000                     60.100000       60.570000
# 25%                 78.150000                     69.250000       66.570000
# ...

# %%
x3=pd.concat([x2, y],axis=1)
x3
# Out:
#      pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 0     0.552632      0.857143                0.000000                0.614770
# 1     0.631579      1.000000                0.795918                0.647837
# 2     0.473684      0.428571                0.693878                0.543125
# 3     0.552632      0.714286                0.112245                0.036098
# 4     0.578947      0.428571                0.224490                0.267567
# ..         ...           ...                     ...                     ...
# 353   0.552632      0.428571                0.887755                0.504547
# 354   0.552632      0.857143                0.000000                0.614770
# 355   0.631579      1.000000                0.795918                0.647837
# 356   0.473684      0.428571                0.693878                0.543125
# 357   0.552632      0.714286                0.112245                0.036098
#
# ...

# %%
# Logistic Regression ML

df=x3
df
# Out:
#      pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 0     0.552632      0.857143                0.000000                0.614770
# 1     0.631579      1.000000                0.795918                0.647837
# 2     0.473684      0.428571                0.693878                0.543125
# 3     0.552632      0.714286                0.112245                0.036098
# 4     0.578947      0.428571                0.224490                0.267567
# ..         ...           ...                     ...                     ...
# 353   0.552632      0.428571                0.887755                0.504547
# 354   0.552632      0.857143                0.000000                0.614770
# 355   0.631579      1.000000                0.795918                0.647837
# 356   0.473684      0.428571                0.693878                0.543125
# 357   0.552632      0.714286                0.112245                0.036098
#
# ...

# %%
# x=df.drop(['perceived#Job#Skill'],axis=1)

# %%
# x1=pd.DataFrame(x)
# x1

# %%
# y=df[['perceived#Job#Skill']]
# y1=pd.DataFrame(y)
# y1

# %%
# from sklearn.model_selection import train_test_split
# x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.25,random_state=42)

# %%
# from sklearn.linear_model import LogisticRegression
# log_reg=LogisticRegression()

# %%
# model=log_reg.fit(x1_train,y1_train)

# %%
y.shape
# Out:
# (358, 7)

# %%
y1_pred=model.predict(x1_test)
y1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 y1_pred=model.predict(x1_test)
#       2 y1
#
# NameError: name 'model' is not defined

# %%
from sklearn.metrics import accuracy_score
print('accuracy score:',accuracy_score(y1_test,y1_pred))
# Out:
# accuracy score: 0.9222222222222223

# %%
# sample prediction
x1_train.head(10)
# Out:
#      pre_score  Age_in_years  Percentage_in_10_Class  Percentage_in_12_Class  \
# 60    0.368421      0.142857                0.530612                0.758060
# 114   0.500000      0.142857                0.403061                0.658859
# 340   0.552632      0.428571                0.887755                0.504547
# 110   0.842105      0.857143                0.275510                0.102232
# 249   0.552632      0.857143                0.479592                0.950951
# 229   0.052632      0.571429                0.806122                0.984018
# 17    0.578947      0.428571                0.224490                0.267567
# 145   0.447368      0.571429                0.326531                0.680904
# 24    0.605263      0.285714                0.377551                0.763571
# 101   0.500000      0.428571                0.696429                0.873794
#
#      Percentage_in_Under_Graduate  post_score  percentage_MBA  Gender  STATE  \
# ...

# %%
y1_train.head(10)
# Out:
#      perceived#Job#Skill
# 60                     1
# 114                    1
# 340                    1
# 110                    0
# 249                    1
# 229                    1
# 17                     1
# 145                    1
# 24                     1
# 101                    1

# %%
print(list(x1_train.loc[340].values))
# Out:
# [np.float64(0.5526315789764542), np.float64(0.4285714285714288), np.float64(0.8877551020408165), np.float64(0.5045467070818406), np.float64(0.4659574468085106), np.float64(0.5436562073669853), np.float64(0.7666666666000002), np.float64(1.0), np.float64(0.0), np.float64(2.0), np.float64(1.0), np.float64(2.0), np.float64(3.0)]

# %%
model.predict([[np.float64(0.5526315789764542), np.float64(0.8571428571428572), np.float64(0.4795918367346934), np.float64(0.9509506751171122), np.float64(0.5440729483282674), np.float64(0.4666666666000001), np.float64(0.8478854024556615), np.float64(0.0), np.float64(4.0), np.float64(2.0), np.float64(0.0), np.float64(2.0), np.float64(2.0)]])
# Out:
# c:\python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from
